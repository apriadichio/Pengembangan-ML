# %%
# !pip install google-play-scraper pandas
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# ## Scraping Data

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# Scrape review dari aplikasi Gojek
app_id = "com.gojek.app"
count = 10000

result, _ = reviews(
    app_id,
    lang='id', 
    country='id',  
    sort=Sort.NEWEST,  # Urutkan berdasarkan yang terbaru
    count=count
)

reviews_df = pd.DataFrame(result)

# Simpan ke CSV 
reviews_df.to_csv("gojek_reviews.csv", index=False)

# %%
reviews_df = pd.read_csv("gojek_reviews.csv")
reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  be344f8b-7bf2-4ede-8fd6-a3156c608824  Pengguna Google
# 1  a2a40ba9-3f43-4cdc-a848-d16d2d99cea3  Pengguna Google
# 2  7b1ac432-3d60-40e8-b0d2-44250db4f4eb  Pengguna Google
# 3  1a455d7f-e5d4-4bc5-af1a-6196f6a945e1  Pengguna Google
# 4  dd84b72a-fcfd-460d-b253-cf2211a67071  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  terus tingkatkan lagi dan berikan inovasi dan ...      5              0
# 1                                    sangat membantu      5              0
# 2                                       numeroo unoo      5              0
# 3                                    sangat membantu      5              0
# 4                                             mantap      5              0
#
#   reviewCreatedVersion                   at replyContent repliedAt appVersion
# 0                  NaN  2025-03-24 16:42:24          NaN       NaN        NaN
# 1               5.15.1  2025-03-24 16:31:35          NaN       NaN     5.15.1
# 2               5.14.2  2025-03-24 16:26:48          NaN       NaN     5.14.2
# 3               4.93.1  2025-03-24 16:14:26          NaN       NaN     4.93.1
# 4                  NaN  2025-03-24 16:05:39          NaN       NaN        NaN
